# %%
from pdf2image import convert_from_path
import cv2
import tempfile
import numpy as np
import pandas as pd
import pickle
import pytesseract
import matplotlib.pyplot as plt

pdf_file="sarcoma_codes.pdf"

table_ocrs=[]
with tempfile.TemporaryDirectory() as path:
    images_from_path = convert_from_path( pdf_file, output_folder=path)
    for image in images_from_path:
        img = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2GRAY)
        
        #img = cv2.rotate(img, cv2.cv2.ROTATE_90_CLOCKWISE)
        thresh, img_bin = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
        img_bin = 255 - img_bin

        kernel_len = np.array(img).shape[1] // 100

        ver_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_len))
        hor_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_len, 1))
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))

        image_1 = cv2.erode(img_bin, ver_kernel, iterations=3)
        vertical_lines = cv2.dilate(image_1, ver_kernel, iterations=3)

        image_2 = cv2.erode(img_bin, hor_kernel, iterations=3)
        horizontal_lines = cv2.dilate(image_2, hor_kernel, iterations=3)

        img_vh = cv2.addWeighted(vertical_lines, 0.5, horizontal_lines, 0.5, 0.0)
    
        img_vh = cv2.erode(~img_vh, kernel, iterations=2)

        thresh, img_vh = cv2.threshold(img_vh, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

        bitxor = cv2.bitwise_xor(img, img_vh)
        bitnot = cv2.bitwise_not(bitxor)
        contours, hierarchy = cv2.findContours(img_vh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

        boundingBoxes = [cv2.boundingRect(c) for c in contours]
        (contours, boundingBoxes) = zip(*sorted(zip(contours, boundingBoxes),
                                            key=lambda b: b[1][1], reverse=False))

        box = []
        for c in contours:
            x, y, w, h = cv2.boundingRect(c)
            image = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            box.append([x, y, w, h])

        row = []
        column = []
        j = 0

        for i in range(len(box)):

            if (i == 0):
                column.append(box[i])
                previous = box[i]

            else:
                if (box[i][1] == previous[1] ):

                    column.append(box[i])
                    previous = box[i]

                    if (i == len(box) - 1):
                        row.append(column)

                else:
                    row.append(column)
                    column = []
                    previous = box[i]
                    column.append(box[i])


        countcol = 0
        for i in range(len(row)):
            countcol = len(row[i])
            if countcol > countcol:
                countcol = countcol


        center = [int(row[i][j][0] + row[i][j][2] / 2) for j in range(len(row[i])) if row[0]]

        center = np.array(center)
        center.sort()

        finalboxes = []
        for i in range(len(row)):
            lis = []
            for k in range(countcol):
                lis.append([])
            for j in range(len(row[i])):
                diff = abs(center - (row[i][j][0] + row[i][j][2] / 4))
                minimum = min(diff)
                indexing = list(diff).index(minimum)
                lis[indexing].append(row[i][j])
            finalboxes.append(lis)

        outer = []
        for i in range(len(finalboxes)):
            for j in range(len(finalboxes[i])):
                inner = ''
                if (len(finalboxes[i][j]) == 0):
                    outer.append(' ')
                else:
                    for k in range(len(finalboxes[i][j])):
                        y, x, w, h = finalboxes[i][j][k][0], finalboxes[i][j][k][1], finalboxes[i][j][k][2], \
                                     finalboxes[i][j][k][3]
                        finalimg = bitnot[x:x + h, y:y + w]
                        kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 1))
                        border = cv2.copyMakeBorder(finalimg, 2, 2, 2, 2, cv2.BORDER_CONSTANT, value=[255, 255])
                        resizing = cv2.resize(border, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
                        dilation = cv2.dilate(resizing, kernel, iterations=1)
                        erosion = cv2.erode(dilation, kernel, iterations=2)

                        out = pytesseract.image_to_string(erosion)
                        if (len(out) == 0):
                            #out = pytesseract.image_to_string(erosion, config='--psm 3')
                            out = pytesseract.image_to_string(erosion)
                        inner = inner + " " + out
                    outer.append(inner)

        arr = np.array(outer)
        dataframe = pd.DataFrame(arr.reshape(len(row), countcol))
        table_ocrs.append(dataframe)
sarcoma_df=pd.concat(table_ocrs, axis=0)

sarcoma_df=(sarcoma_df.applymap(lambda x: x.replace("\n"," ")))
sarcoma_df=(sarcoma_df.applymap(lambda x: x[:-2]))
sarcoma_df=sarcoma_df[~sarcoma_df[0].str.contains(" Morphological codes ")]
sarcoma_df=(sarcoma_df.applymap(lambda x: x.replace("NOS","")))
sarcoma_df=(sarcoma_df.applymap(lambda x: x.replace(",","")))
sarcoma_df=sarcoma_df.reset_index(drop=True)

tumour_category=[" Adipocytic tumours"," Fibroblastic/myofibroblastic tumours",
              " So-called fibrohistiocytic tumours"," Smooth muscle tumours"," Skeletal muscle tumours",
             " Vascular tumours"," Nerve sheath tumours",
              " Chondro-osseus tumours"," Tumours of uncertain differentiation"]
tumour_type=[" Intermediate (locally aggressive)"," Intermediate (rarely metastasizing)", " Malignant"]


sarcoma_df["tumour_category"]=""
category_indices=sarcoma_df.index[sarcoma_df[0].isin(tumour_category) ].tolist()
category_indices.append(sarcoma_df.shape[0])
ranges=list(zip(category_indices[:-1], category_indices[1:]))

for enum,(start, end) in enumerate(ranges):
    sarcoma_df["tumour_category"].iloc[start:end]=sarcoma_df[0].iloc[start]

sarcoma_df["tumour_type"]=""
type_indices=sarcoma_df.index[sarcoma_df[0].isin(tumour_type) ].tolist()
type_indices.append(sarcoma_df.shape[0])
ranges=list(zip(type_indices[:-1], type_indices[1:]))
for enum,(start, end) in enumerate(ranges):
    sarcoma_df["tumour_type"].iloc[start:end]=sarcoma_df[0].iloc[start]
indexes_to_keep = set(range(sarcoma_df.shape[0])) - set(type_indices+category_indices)
sarcoma_df = sarcoma_df.take(list(indexes_to_keep))
sarcoma_df=sarcoma_df.reset_index(drop=True)
sarcoma_df=sarcoma_df.drop([2,3], axis=1)
sarcoma_df=sarcoma_df.drop(index=0)
sarcoma_df=sarcoma_df.rename(columns={0: "subtype", 1: "code", 2: "subtype-detail"})

# %%
sarcoma_df["subtype"]=(sarcoma_df["subtype"].apply(lambda x: x.lower()))
sarcoma_subtypes=sarcoma_df["subtype"].values.tolist()

# %%
import json
from collections.abc import Iterable

def load_config_file(nfile, abspath=False):

    ext = '.json' if 'json' not in nfile else ''
    pre = '' if abspath else './'
    fp = open(pre + nfile + ext, 'r')

    s = ''

    for l in fp:
        s += l

    return json.loads(s)


def flatten(l):
    for el in l:
        if isinstance(el, Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el

# %%
tumour_types=load_config_file("subtypes.json")
tumour_types = pd.DataFrame(tumour_types)
#benign_subtypes=[el.lower() for el in list(flatten(tumour_types.values.tolist())) if isinstance(el, str)]

# %%
# Out:
#                                                                     Adipocytic tumours  \
# Benign                               [Fibrolipoma, Lipomatosis, Lipomatosis of nerv...
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                                                             [myxoid sarcoma]
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                   Fibroblastic/myofibroblastic tumours  \
# Benign                               [Nodular fasciitis, Proliferative fasciitis, P...
# Intermediate (rarely metastasizing)  [Solitary fibrous tumour, Solitary fibrous tum...
# Malignant                                                                          NaN
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                     So-called fibrohistiocytic tumours  \
# Benign                               [Tenosynovial giant cell tumour, Tenosynovial ...
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                                                                          NaN
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                                  Smooth-muscle tumours  \
# Benign                               [Leiomyoma, smooth muscle neoplasm, smooth mus...
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                                                                          NaN
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                                Skeletal-muscle tumours  \
# Benign                                                                   [Rhabdomyoma]
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                            [Epithelioid hemangioendothelioma, Angiosarcom...
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                                   Nerve sheath tumours  \
# Benign                               [Schwannoma, Melanotic schwannoma, Neurofibrom...
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                                                              [Neuroblastoma]
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                     Chondro-osseus tumours  \
# Benign                                                 NaN
# Intermediate (rarely metastasizing)                    NaN
# Malignant                                 [chondrosarcoma]
# Not identified                                         NaN
# other                                                  NaN
#
#                                                       Gastrointestinal stromal tumours  \
# Benign                                [Benign gastrointestinal stromal (tumour|tumor)]
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                            [Gastrointestinal stromal tumour, Gastrointest...
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                   Tumours of uncertain differentiation  \
# Benign                               [Acral fibromyxoma, Intramuscular myxoma, Juxt...
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                               [synovial sarcoma, Pleomorphic dermal sarcoma]
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                               Undifferentiated / unclassified sarcomas  \
# Benign                                                                             NaN
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                            [spindle cell sarcoma, pleomorphic sarcoma, ro...
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                                    Notochordal_tumours  \
# Benign                               [Benign notochordal tumour, Benign notochordal...
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                                                                   [Chordoma]
# Not identified                                                                     NaN
# other                                                                              NaN
#
#                                                                     Other not sarcomas  \
# Benign                                                               [epidermoid cyst]
# Intermediate (rarely metastasizing)                                                NaN
# Malignant                            [Melanoma, Adenosarcoma, Adenoid cystic carcin...
# Not identified                                                                     NaN
# other                                [rheumatoid arthritis, endometriosis, fibrosis...
#
#                                     Uncertain morphology
# Benign                                               NaN
# Intermediate (rarely metastasizing)                  NaN
# Malignant                                            NaN
# Not identified                               [uncertain]
# other                                                NaN

# %%
#subtypes=sarcoma_df["subtype"].values.tolist()+ tumour_types

# %%
tumour_category=[]
tumour_subtypes=[]
for i, columns in tumour_types.iterrows():
    for column in columns:
           if isinstance(column, list):
                tumour_subtypes.extend(column)
                tumour_category.extend([i]*len(column))

# %%
benign_tumours=np.vstack((tumour_subtypes, tumour_category))

# %%
benign_tumours=pd.DataFrame(np.transpose(benign_tumours), columns=["subtype","tumour_type"])

# %%
sarcoma_df=sarcoma_df[["subtype", "tumour_type"]]

frames = [sarcoma_df, benign_tumours]
  
soft_tissue_tumours = pd.concat(frames)

# %%
soft_tissue_tumours["subtype"]=soft_tissue_tumours["subtype"].apply(lambda x: x.lower())

# %%
soft_tissue_tumours.to_csv("soft_tissue_tumours.csv")

# %%
subtype_regex=("|".join(soft_tissue_tumours["subtype"].values.tolist()))

# %%
subtype_regex
# Out:
# ' atypical lipomatous tumour| well-differentiated liposarcoma| dedifferentiated liposarcoma| myxoid liposarcoma| pleomorphic liposarcoma| liposarcoma not otherwise specified| palmar/plantar type fibromatosis| desmoid-type fibromatosis| lipofibromatosis| giant cell fibroblastoma| dermatofibrosarcoma protuberans| fibrosarcomatous dermatofibrosarcoma protuberans| pigmented dermatofibrosarcoma protuberans| solitary fibrous tumour| solitary fibrous tumour malignant| inflammatory myofibroblastic sarcoma| low grade myofibroblastic sarcoma| myxoinflammatory fibroblastic sarcoma| infantile fibrosarcoma| adult fibrosarcoma| myxofibrosarcoma| low-grade fibromyxoid sarcoma| sclerosing epithelioid fibrosarcoma| plexiform fibrohistiocytic tumour| giant cell tumour of soft tissue| leiomyosarcoma| embryonal rhabdomyosarcoma (including botryoid anaplastic)| alveolar rhabdomyosarcoma (including solid anaplastic)| pleomorphic rhabdomyosarcoma| spindle cell/sclerosing rhabdomyosarcoma| kaposiform haemangioendothelioma| retiform haemangioendothelioma| papillary intralymphatic angioendothelioma| composite haemangioendothelioma| pseudomyogenic (epithelioid sarcoma-like) haemangioendothelioma| kaposi sarcoma| epithelioid haemangioendothelioma| angiosarcoma of soft tissue| malignant peripheral nerve sheath tumour| epithelioid malignant peripheral nerve sheath tumour| malignant triton tumour| malignant granular cell tumour| ectomesenchymoma| mesenchymal chondrosarcoma| extraskeletal osteosarcoma| haemosiderotic fibrolipomatous tumour| atypical fibroxanthoma| angiomatoid fibrous histiocytoma| ossifying fibromyxoid tumour malignant| mixed tumour  malignant| myoepithelial carcinoma| phosphaturic mesenchymal tumour malignant| synovial sarcoma | synovial sarcoma spindle cell| synovial sarcoma biphasic| epithelioid sarcoma| alveolar soft-part sarcoma| clear cell sarcoma of soft tissue| extraskeletal myxoid chondrosarcoma| extraskeletal ewing sarcoma| desmoplastic small round cell tumour| extra-renal rhabdoid tumour| neoplasms with perivascular epithelioid cell differentiation (pecoma) 1 pecoma malignant| intimal sarcoma|fibrolipoma|lipomatosis|lipomatosis of nerve|lipoblastoma|lipoblastomatosis|angiolipoma|myolipoma of soft tissue|chondroid lipoma|extra-renal angiomyolipoma|extra-adrenal myelolipoma|spindle cell lipoma|pleomorphic lipoma|hibernoma|lipoma(?!.*like)|lipoma|dedifferentiated adipocytic neoplasm|nodular fasciitis|proliferative fasciitis|proliferative myositis|myositis ossifficans|fibro-osseous pseudotumour|ischemic fasciitis|elastofibroma|fibrous hamartoma|fibromatosis colli|juvenile hyaline fibromatosis|inclusion body fibromatosis|fibroma of tendon sheath|desmoplastic fibroblastoma|mammary-type myofibroblastoma|myofibroblastoma|calcifying aponeurotic fibroma|angiomyofibroblastoma|cellular angiofibroma|nuchal-type fibroma|gardner fibroma|calcifying fibrous (tumour|tumor)|tenosynovial giant cell tumour|tenosynovial giant cell tumor|tenosynovial giant cell tumour localized type|tenosynovial giant cell tumor localized type|tenosynovial giant cell tumour diffuse type|tenosynovial giant cell tumor diffuse type|deep benign fibrous tumor|deep benign fibrous tumour|leiomyoma|smooth muscle neoplasm|smooth muscle tumor|smooth muscle tumour|rhabdomyoma|schwannoma|melanotic schwannoma|neurofibroma|plexiform neurofibroma|perineurioma|ganglioneuroma|malignant perineurioma|granular cell (tumour|tumor)|dermal nerve sheath myxoma|myxoma|solitary circumscribed neuroma|ectopic meningioma|nasal glial heterotopia|benign triton tumour|hybrid nerve (tumour|tumor)s|benign gastrointestinal stromal (tumour|tumor)|acral fibromyxoma|intramuscular myxoma|juxta-articular myxoma|deep angiomyxoma|pleomorphic hyalinizing angiectatic (tumour|tumor)|ectopic hamartomatous thymoma|benign notochordal tumour|benign notochordal tumor|epidermoid cyst|solitary fibrous tumour|solitary fibrous tumor|dermatofibrosarcoma|myxoid sarcoma|epithelioid hemangioendothelioma|angiosarcoma|rhabdomyos ...

# %%
def rotateImage(cvImage, angle: float):
    newImage = cvImage.copy()
    (h, w) = newImage.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    newImage = cv2.warpAffine(newImage, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return newImage


def getSkewAngle(cvImage) -> float:
    # Prep image, copy, convert to gray scale, blur, and threshold
    
    newImage = cvImage.copy()
    gray = cv2.cvtColor(newImage, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (9, 9), 0)
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    # Apply dilate to merge text into meaningful lines/paragraphs.
    # Use larger kernel on X axis to merge characters into single line, cancelling out any spaces.
    # But use smaller kernel on Y axis to separate between different blocks of text
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 5))
    dilate = cv2.dilate(thresh, kernel, iterations=5)

    # Find all contours
    contours, hierarchy = cv2.findContours(dilate, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key = cv2.contourArea, reverse = True)

    # Find largest contour and surround in min area box
    largestContour = contours[0]
    minAreaRect = cv2.minAreaRect(largestContour)

    # Determine the angle. Convert it to the value that was originally used to obtain skewed image
    angle = minAreaRect[-1]
    if angle < -45:
        angle = 90 + angle
    return -1.0 * angle

# Deskew image
def deskew(cvImage):
    angle = getSkewAngle(cvImage)
    return rotateImage(cvImage, -1.0 * angle)

# %%
from pdfreader import pdfReader, medicalDb
import os
import json
import pickle
import re
import os
from pdf2image import convert_from_path, exceptions
import pytesseract
import pandas as pd


pdf_dir="medical_reports"

pdf_files=os.listdir(pdf_dir)

# %%
from nltk.corpus import wordnet
import collections
synonyms = collections.defaultdict(list)


duplicates=[]
words_of_interest=["highly","represent","suggestive","suggest","features"]
for word in words_of_interest:
    for syn in wordnet.synsets(word):
        for l in syn.lemmas():
            duplicates.append(l.name())
           
    synonyms[word]=(list(set(duplicates)))


expressions = [
    "(?:(?:features|findings|this|tumour)\s*(?:are|is)\s*consistent\s*with|"
    "(?:would\s*be|are|is)(?!not)(?:.*?)(?:in\s*keeping\s*with\s*)|"
    "features\s*(?:.*?)are\sof\s*|"
    "(features|diagnosis)(?!not)(?:.*?)(?:{})*".format("|".join(synonyms["suggest"]))+"|"
    "(is|are)\s*interpreted\s*as\s*(?!.*negative)|"
    "(?:could|might|might\s*possibly|most\s*likely|may)\s*(?!not)(?:{})".format("|".join(synonyms["represent"]))+"|"
    "(?:features|findings|this|tumour|morphology)\s*(?:are|is)\s*(?!not)(?:.*?)\s*(?:suggestive)\s*of|"
    "(?:{})\s*(?:suspicious)\s*of".format("|".join(synonyms["highly"]))+"|"
    "features\s*(?:.*?)(?:favor|favoring|favouring)|"
    "(?:features|morphology)\s*(?:in keeping\s*with\s*))"
    "(.*?(;|\.)+?)"]

# %%
expressions = [
    "(?:features|findings|this|tumour)\s*(?:are|is)\s*consistent\s*with(.*?(;|\.)+?)",
    "(?:would\s*be|are|is)(?!not)(?:.*?)(?:in\s*keeping\s*with\s*(.*?(;|\.)+?))",
    "features\s*(?:.*?)are\sof\s*(.*?(;|\.)+?)",
    "features\s*(?:.*?)(?:favor|favoring|favouring)(.*?(;|\.)+?)",
    "(?:features|morphology)\s*(?:in keeping\s*with\s*)(.*?(;|\.)+?)",
    "(features|diagnosis)(?!.*not)(?:.*?)(?:{})*(.*?(;|\.)+?)".format("|".join(synonyms["suggest"])),
    "(?:features|findings|this|tumour|morphology)\s*(?:are|is)\s*(?!.*not)(?:.*?)\s*(?:suggestive)\s*of(.*?(;|\.)+?)",
    "(is|are)\s*interpreted\s*as\s*(?!.*negative)(.*?(;|\.)+?)",
    "(?:could|might|might\s*possibly|most\s*likely|may)\s*(?!.*not)(?:{})(.*?(;|\.)+?)".format("|".join(synonyms["represent"])),
    "(?:{})\s*(?:suspicious)\s*of(.*?(;|\.)+?)".format("|".join(synonyms["highly"])), 
   ]

# %%
from PIL import Image
import nltk
import cv2
import itertools

patient_records=[]


pdf_dir="medical_reports"

pdf_files=os.listdir(pdf_dir)

regex=[r'([A-Z]?[0-9]{5,12})',
       "(\d{4}(:?(/|\s))\d{2})",
       r"(?:Sex|\d{1,2} (?:YEAR-OLD|YEAR OLD|year old))+ (\w)",
       r'(\d{1,2}) (?:YEAR-OLD|YEAR OLD|year old)+',
       r'grade (\d{1,2})']


for pdf_file in pdf_files:
    #file_name=(os.path.splitext(os.path.basename(pdf_file))[0])
    
    keys = ["Patient","Lab No","Sex","Age","Grade"]
    patient_dir = collections.defaultdict(list)
        
    text=''
    if pdf_file.endswith(".pdf"):
            try:
                    images=convert_from_path(os.path.join(pdf_dir,pdf_file))
                    for image in images:
                        text += str(pytesseract.image_to_string(image))
            except exceptions.PDFPageCountError:
                    raise ValueError('Exception: PDFPageCountError for %s' % path)
    
    elif pdf_file.endswith(".jpg"):     
            img = cv2.imread(os.path.join(pdf_dir,pdf_file))

            rotated=deskew(img)

            text += str(pytesseract.image_to_string(rotated))
            text=text.replace("\n"," ")
    else:
            print ("The file does not have the required format {}".format(pdf_file))
            continue
            
    for enum,k in enumerate(keys):
        try:
                patient_dir[k]=re.search(regex[enum], text, re.MULTILINE | re.DOTALL).group(1)
                
        except AttributeError:
                print ("There is no information available in {} for field {}".format(pdf_file,k))
            
    if not patient_dir["Patient"]:
                     patient_dir["Patient"]=os.path.splitext(pdf_file)[0]
    
    patient_dir["report_file"]=os.path.join(os.path.join(pdf_dir,pdf_file))
        
    sentences = nltk.tokenize.sent_tokenize(text)
    
    for sentence, expression in itertools.product(sentences, expressions):
            try:
                match=re.search(expression, sentence, re.MULTILINE | re.DOTALL).group(0)
                match=match.replace("well- differentiated liposarcoma","well-differentiated liposarcoma")

                if match:
                    subtype=re.search(subtype_regex,match.lower(), re.MULTILINE | re.DOTALL).group(0)
                    if subtype:
                        patient_dir["Diagnosis"].append(subtype)
                        break 
            except AttributeError:
                    pass
    patient_records.append(patient_dir)
# Out:
# There is no information available in 746516.jpg for field Grade
# There is no information available in 752384.jpg for field Grade
# There is no information available in 742180.pdf for field Grade
# There is no information available in 736259.pdf for field Age
# There is no information available in 737695.pdf for field Lab No
# There is no information available in 737695.pdf for field Sex
# There is no information available in 737695.pdf for field Age
# There is no information available in 737695.pdf for field Grade
# There is no information available in 740278.jpg for field Grade
# There is no information available in 749189.pdf for field Grade
# There is no information available in 740690.pdf for field Lab No
# There is no information available in 740690.pdf for field Grade
# There is no information available in 574148.pdf for field Grade
# There is no information available in 745337.pdf for field Grade
# There is no information available in 749815.jpg for field Grade
# There is no information available in 667098.jpg for field Grade
# There is no information available in 746528.jpg for field Grade
# There is no information available in 749870.jpg for field Grade
# There is no information available in 746764.jpg for field Grade
# There is no information available in 742276.pdf for field Grade
# There is no information available in 380577.pdf for field Grade
# There is no information available in 731672.pdf for field Age
# There is no information available in 731672.pdf for field Grade
# There is no information available in 740198.pdf for field Grade
# There is no information available in 749963.pdf for field Grade
# There is no information available in 742442.pdf for field Grade
# There is no information available in 741139.pdf for field Grade
# There is no information available in 749443.jpg for field Grade
# There is no information available in 398221.jpg for field Grade
# There is no information available in 750361.pdf for field Grade
# There is no information available in 750248.jpg for field Grade
# There is no information available in unknown.pdf for field Patient
# There is no information available in unknown.pdf for field Lab No
# There is no information available in 752503.jpg for field Grade
# There is no information available in 747281.jpg for field Grade
# There is no information available in 748808.pdf for field Grade
# There is no information available in 748001.pdf for field Grade
# There is no information available in 732874.pdf for field Grade
# There is no information available in 570034.jpg for field Grade
# There is no information available in 692634.pdf for field Grade
# There is no information available in 746534.pdf for field Grade
# There is no information available in 551466.jpg for field Grade
# There is no information available in 749968.jpg for field Grade
# There is no information available in 519535.pdf for field Grade
# There is no information available in 20741727.pdf for field Grade
# There is no information available in 381305.jpg for field Grade
# There is no information available in 742419.pdf for field Grade
# There is no information available in 725466.jpg for field Grade
# There is no information available in 742590.pdf for field Grade
# There is no information available in 742429.pdf for field Grade
# There is no information available in 741021.jpg for field Grade
# There is no information available in 617727.jpg for field Grade
# There is no information available in 738247.jpg for field Grade
# There is no information available in 748278.jpg for field Grade
# There is no information available in 750186.jpg for field Grade
# There is no information available in 741071.pdf for field Grade
# There is no information available in 745101.jpg for field Grade
# There is no information available in 749887.jpg for field Grade
# There is no information available in 6129041934.jpg for field Grade
# There is no information available in 728484.jpg for field Grade
# There is no information available in 731785.jpg for field Grade
# There is no information available in 735988.pdf for field Grade
# There is no information available in 646260.jpg for field Grade
# There is no information available in 1440201465.pdf for field Grade
# There is no information available in 740086.pdf for field Grade
# There is no information available in 751381.jpg for field Grade
# There is no information available in 741054.pdf for field Grade
# There is no information available in 742225.jpg for field Grade
# There is no information available in 616826.pdf for field Grade
# There is no information available in 635102.jpg for field Grade
# There is no information available in 752434.jpg for field Grade
# There is no information available in 740069.pdf for field Grade
# There is no information available in 741709.pdf for field Grade
# There is no information available in 380073.jpg for field Grade
# There is no information available in 6261275661.jpg for field Grade
# There is no information available in 745029.pdf for field Grade
# There is no information available in 736152.jpg for field Grade
# There is no information available in 749805.pdf for field Grade
# There is no information available in 729483.pdf for field Grade
# There is no information available in 594889.jpg for field Grade
# There is no information available in 746704.pdf for field Grade
# There is no information available in 739990.pdf for field Grade
# There is no information available in 744246.jpg for field Grade
# There is no information available in 746397.jpg for field Grade
# There is no information available in 742494.pdf for field Grade
# There is no information available in 731349.pdf for field Grade
# There is no information available in 752662.jpg for field Grade
# There is no information available in 746526_2.jpg for field Grade
# There is no information available in 748849.jpg for field Grade
# There is no information available in 739986.pdf for field Lab No
# There is no information available in 749843.jpg for field Grade
# There is no information available in 7080630150.pdf for field Grade
# There is no information available in 680138.jpg for field Sex
# There is no information available in 680138.jpg for field Age
# There is no information available in 680138.jpg for field Grade
# There is no information available in 742620.pdf for field Grade
# There is no information available in 750828.jpg for field Grade
# There is no information available in H14404.pdf for field Grade
# There is no information available in 752433.jpg for field Grade
# There is no information available in 393265.jpg for field Grade
# There is no information available in 732930.jpg for field Grade
# There is no information available in 698711.pdf for field Grade
# There is no information available in 548844.pdf for field Grade
# There is no information available in 740197.pdf for field Grade
# There is no information available in 741269.pdf for field Grade
# There is no information available in 721973.pdf for field Grade
# There is no information available in 751975.jpg for field Grade
# There is no information available in 728324.pdf for field Lab No
# There is no information available in 728324.pdf for field Grade
# There is no information available in 750907.jpg for field Grade
# There is no information available in 4108091108.pdf for field Grade
# There is no information available in 745512.jpg for field Grade
# There is no information available in 733266.jpg for field Grade
# There is no information available in 742663.pdf for field Grade
# There is no information available in 751380.jpg for field Grade
# There is no information available in 746848.jpg for field Grade
# There is no information available in 750077.jpg for field Grade
# There is no information available in 711086.pdf for field Age
# There is no information available in 749042.pdf for field Grade
# There is no information available in 746454.jpg for field Grade
# There is no information available in 747026.jpg for field Grade
# There is no information available in 729823.jpg for field Grade
# There is no information available in 743965.pdf for field Grade
# There is no information available in 725910.jpg for field Grade
# There is no information available in 4688493924.pdf for field Grade
# There is no information available in 739357.jpg for field Grade
# There is no information available in 749052.pdf for field Grade
# There is no information available in 743984.jpg for field Grade
# There is no information available in 731916.jpg for field Grade
# There is no information available in 746293.jpg for field Grade
# There is no information available in 749860.jpg for field Grade
# There is no information available in 740567.jpg for field Grade
# There is no information available in 751277.jpg for field Grade
# There is no information available in 615457.pdf for field Sex
# There is no information available in 615457.pdf for field Age
# There is no information available in 588674.jpg for field Grade
# There is no information available in 740094.pdf for field Grade
# There is no information available in 748839.jpg for field Grade
# There is no information available in 686845.jpg for field Grade
# There is no information available in 746364.jpg for field Grade
# There is no information available in 742392.jpg for field Grade
# There is no information available in 750836.jpg for field Grade
# There is no information available in 656644.jpg for field Grade
# There is no information available in 749825.jpg for field Grade
# There is no information available in 744945.jpg for field Grade
# There is no information available in 751369.jpg for field Grade
# There is no information available in 741707.jpg for field Grade
# There is no information available in 743368.pdf for field Grade
# There is no information available in 741420.pdf for field Grade
# There is no information available in 741541.jpg for field Grade
# There is no information available in 737791.pdf for field Grade
# There is no information available in H28617.jpg for field Age
# There is no information available in 747842.jpg for field Grade
# There is no information available in 742533.pdf for field Sex
# There is no information available in 742533.pdf for field Age
# There is no information available in 742533.pdf for field Grade
# There is no information available in 741615.pdf for field Grade
# There is no information available in H28613.jpg for field Age
# There is no information available in 733267.pdf for field Grade
# There is no information available in 752408.jpg for field Grade
# There is no information available in 753034.jpg for field Grade
# There is no information available in 753211.jpg for field Grade
# There is no information available in 741075.jpg for field Grade
# There is no information available in 743981.jpg for field Grade
# There is no information available in 750845.jpg for field Grade
# There is no information available in 752459.jpg for field Grade
# There is no information available in 755068.jpg for field Grade
# There is no information available in 745625.jpg for field Grade
# There is no information available in 751524.jpg for field Grade
# There is no information available in 742872.pdf for field Grade
# There is no information available in 746569.pdf for field Grade
# There is no information available in 740093.jpg for field Grade
# There is no information available in 741366.jpg for field Grade
# There is no information available in 744911.pdf for field Grade
# There is no information available in 749835.pdf for field Grade
# There is no information available in 753040.jpg for field Grade
# There is no information available in 753315.jpg for field Grade
# There is no information available in 742120.jpg for field Grade
# There is no information available in 750847.jpg for field Grade
# There is no information available in 742799.pdf for field Grade
# There is no information available in 749814.jpg for field Grade
# There is no information available in 731794.pdf for field Grade
# There is no information available in H28596.jpg for field Grade
# There is no information available in 655933.jpg for field Grade
# There is no information available in 746569.jpg for field Grade
# There is no information available in 540687.pdf for field Grade
# There is no information available in 20747281.pdf for field Grade
# There is no information available in 4462713850.pdf for field Grade
# There is no information available in DOC093-9-10.pdf for field Patient
# There is no information available in DOC093-9-10.pdf for field Lab No
# There is no information available in DOC093-9-10.pdf for field Grade
# There is no information available in 651433.jpg for field Grade
# There is no information available in 650958.jpg for field Grade
# There is no information available in 752446.jpg for field Grade
# There is no information available in 740902.jpg for field Grade
# There is no information available in 529889.pdf for field Grade
# There is no information available in 4181777839.jpg for field Grade
# There is no information available in 745629.jpg for field Grade
# There is no information available in 752457.jpg for field Grade
# There is no information available in 746525.jpg for field Grade
# There is no information available in 740913.pdf for field Patient
# There is no information available in 740913.pdf for field Lab No
# There is no information available in 740913.pdf for field Grade
# There is no information available in 714203.pdf for field Grade
# There is no information available in 739537.jpg for field Grade
# There is no information available in 703664.jpg for field Age
# There is no information available in 4683550008.jpg for field Grade
# There is no information available in 749963.jpg for field Grade
# There is no information available in 746364.pdf for field Grade
# There is no information available in 741773.jpg for field Grade
# There is no information available in 752587.jpg for field Grade
# There is no information available in 740385.pdf for field Grade
# There is no information available in 741850.jpg for field Grade
# There is no information available in 742095.jpg for field Grade
# There is no information available in 745153.jpg for field Grade
# There is no information available in 750804.jpg for field Grade
# There is no information available in 748836.pdf for field Grade
# There is no information available in 740255.jpg for field Grade
# There is no information available in 721973.jpg for field Grade
# There is no information available in 752415.jpg for field Grade
# There is no information available in 749815.pdf for field Grade
# There is no information available in 743474.jpg for field Grade
# There is no information available in 747140.jpg for field Grade
# The file does not have the required format .DS_Store
# There is no information available in 648037.jpg for field Grade
# There is no information available in 744378.jpg for field Grade
# There is no information available in 746824.jpg for field Grade
# There is no information available in 607460.pdf for field Lab No
# There is no information available in 736488.pdf for field Lab No
# There is no information available in 736488.pdf for field Grade
# There is no information available in 741771.jpg for field Grade
# There is no information available in 748891.pdf for field Grade
# There is no information available in 6250045082.jpg for field Grade
# There is no information available in 740093.pdf for field Grade
# There is no information available in 741711.jpg for field Grade
# There is no information available in 662198.jpg for field Grade
# There is no information available in 751165.jpg for field Grade
# There is no information available in 4987958562.jpg for field Grade
# There is no information available in 740477.jpg for field Grade
# There is no information available in 747015.jpg for field Grade
# There is no information available in 4445753947.jpg for field Grade
# There is no information available in 745095.jpg for field Grade
# There is no information available in 744243.jpg for field Grade
# There is no information available in 746770.jpg for field Grade
# There is no information available in 696401.pdf for field Grade
# There is no information available in 736363.jpg for field Grade
# There is no information available in H28616.jpg for field Grade

# %%
records=pd.DataFrame(patient_records)

# %%
patient_records
# Out:
# [defaultdict(list,
#              {'Patient': '746516',
#               'Lab No': '4066 20',
#               'Sex': 'F',
#               'Age': '21',
#               'report_file': 'medical_reports/746516.jpg'}),
#  defaultdict(list,
#              {'Patient': '741984',
#               'Lab No': '2392 20',
#               'Sex': 'M',
#               'Age': '59',
#               'Grade': '2',
#               'report_file': 'medical_reports/741984.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '726249',
#               'Lab No': '8150/20',
#               'Sex': 'M',
#               'Age': '81',
#               'Grade': '3',
#               'report_file': 'medical_reports/726249.jpg',
#               'Diagnosis': ['fibrosis']}),
#  defaultdict(list,
#              {'Patient': '752384',
#               'Lab No': '8805/20',
#               'Sex': 'M',
#               'Age': '68',
#               'report_file': 'medical_reports/752384.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '742180',
#               'Lab No': '2180: 10',
#               'Sex': 'F',
#               'Age': '61',
#               'report_file': 'medical_reports/742180.pdf',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '736259',
#               'Lab No': '0604/20',
#               'Sex': 'F',
#               'Grade': '1',
#               'report_file': 'medical_reports/736259.pdf',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '737695',
#               'report_file': 'medical_reports/737695.pdf',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '678367',
#               'Lab No': '3384/20',
#               'Sex': 'F',
#               'Age': '71',
#               'Grade': '3',
#               'report_file': 'medical_reports/678367.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '740278',
#               'Lab No': '3764 20',
#               'Sex': 'F',
#               'Age': '65',
#               'report_file': 'medical_reports/740278.jpg',
#               'Diagnosis': ['myofibroblastoma']}),
#  defaultdict(list,
#              {'Patient': '749189',
#               'Lab No': '6395 20',
#               'Sex': 'F',
#               'Age': '22',
#               'report_file': 'medical_reports/749189.pdf',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '744062',
#               'Lab No': '1698 20',
#               'Sex': 'F',
#               'Age': '53',
#               'Grade': '3',
#               'report_file': 'medical_reports/744062.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '740690',
#               'Sex': 'F',
#               'Age': '61',
#               'report_file': 'medical_reports/740690.pdf',
#               'Diagnosis': ['fibrolipoma']}),
#  defaultdict(list,
#              {'Patient': '752665',
#               'Lab No': '8513/20',
#               'Sex': 'M',
#               'Age': '76',
#               'Grade': '2',
#               'report_file': 'medical_reports/752665.jpg'}),
#  defaultdict(list,
#              {'Patient': '690405',
#               'Lab No': '7079/20',
#               'Sex': 'M',
#               'Age': '34',
#               'Grade': '3',
#               'report_file': 'medical_reports/690405.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '574148',
#               'Lab No': '6301/20',
#               'Sex': 'M',
#               'Age': '55',
#               'report_file': 'medical_reports/574148.pdf',
#               'Diagnosis': ['fibrosis']}),
#  defaultdict(list,
#              {'Patient': '723014',
#               'Lab No': '5377 20',
#               'Sex': 'F',
#               'Age': '75',
#               'Grade': '2',
#               'report_file': 'medical_reports/723014.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '745337',
#               'Lab No': '3032/20',
#               'Sex': 'M',
#               'Age': '18',
#               'report_file': 'medical_reports/745337.pdf',
#               'Diagnosis': ['rhabdomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '740221',
#               'Lab No': '3181/20',
#               'Sex': 'M',
#               'Age': '44',
#               'Grade': '2',
#               'report_file': 'medical_reports/740221.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749815',
#               'Lab No': '8617/20',
#               'Sex': 'F',
#               'Age': '73',
#               'report_file': 'medical_reports/749815.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '667098',
#               'Lab No': '8551/20',
#               'Sex': 'F',
#               'Age': '47',
#               'report_file': 'medical_reports/667098.jpg',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '746528',
#               'Lab No': '4064 20',
#               'Sex': 'F',
#               'Age': '57',
#               'report_file': 'medical_reports/746528.jpg',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '751523',
#               'Lab No': '7756/20',
#               'Sex': 'M',
#               'Age': '73',
#               'Grade': '3',
#               'report_file': 'medical_reports/751523.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '750034',
#               'Lab No': '7861/20',
#               'Sex': 'F',
#               'Age': '65',
#               'Grade': '3',
#               'report_file': 'medical_reports/750034.jpg',
#               'Diagnosis': ['rhabdomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '749870',
#               'Lab No': '7546/20',
#               'Sex': 'M',
#               'Age': '71',
#               'report_file': 'medical_reports/749870.jpg',
#               'Diagnosis': ['angiosarcoma']}),
#  defaultdict(list,
#              {'Patient': '746764',
#               'Lab No': '4269 20',
#               'Sex': 'F',
#               'Age': '51',
#               'report_file': 'medical_reports/746764.jpg',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '752349',
#               'Lab No': '8396/20',
#               'Sex': 'F',
#               'Age': '59',
#               'Grade': '3',
#               'report_file': 'medical_reports/752349.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '742276',
#               'Lab No': '6970/20',
#               'Sex': 'M',
#               'Age': '58',
#               'report_file': 'medical_reports/742276.pdf',
#               'Diagnosis': ['elastofibroma']}),
#  defaultdict(list,
#              {'Patient': '380577',
#               'Lab No': '5394 20',
#               'Sex': 'F',
#               'Age': '71',
#               'report_file': 'medical_reports/380577.pdf'}),
#  defaultdict(list,
#              {'Patient': '731672',
#               'Lab No': '3468/20',
#               'Sex': 'F',
#               'report_file': 'medical_reports/731672.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '740198',
#               'Lab No': '1280 20',
#               'Sex': 'M',
#               'Age': '37',
#               'report_file': 'medical_reports/740198.pdf',
#               'Diagnosis': ['epidermoid cyst']}),
#  defaultdict(list,
#              {'Patient': '698984',
#               'Lab No': '8833/20',
#               'Sex': 'M',
#               'Age': '66',
#               'Grade': '2',
#               'report_file': 'medical_reports/698984.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749844',
#               'Lab No': '7899/20',
#               'Sex': 'M',
#               'Age': '73',
#               'Grade': '3',
#               'report_file': 'medical_reports/749844.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749963',
#               'Lab No': '6694/20',
#               'Sex': 'M',
#               'Age': '49',
#               'report_file': 'medical_reports/749963.pdf',
#               'Diagnosis': ['myxoma']}),
#  defaultdict(list,
#              {'Patient': '742442',
#               'Lab No': '1265/20',
#               'Sex': 'M',
#               'Age': '33',
#               'report_file': 'medical_reports/742442.pdf',
#               'Diagnosis': ['gastrointestinal stromal tumour']}),
#  defaultdict(list,
#              {'Patient': '741139',
#               'Lab No': '2003 20',
#               'Sex': 'M',
#               'Age': '30',
#               'report_file': 'medical_reports/741139.pdf',
#               'Diagnosis': ['dermatofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '750050',
#               'Lab No': '6696/20',
#               'Sex': 'F',
#               'Age': '88',
#               'Grade': '2',
#               'report_file': 'medical_reports/750050.pdf',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '749443',
#               'Lab No': '7563/20',
#               'Sex': 'F',
#               'Age': '72',
#               'report_file': 'medical_reports/749443.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '398221',
#               'Lab No': '8103/20',
#               'Sex': 'F',
#               'Age': '60',
#               'report_file': 'medical_reports/398221.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '16152',
#               'Lab No': '6152/19',
#               'Sex': 'M',
#               'Age': '79',
#               'Grade': '2',
#               'report_file': 'medical_reports/738249.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '739991',
#               'Lab No': '4440/20',
#               'Sex': 'm',
#               'Age': '76',
#               'Grade': '3',
#               'report_file': 'medical_reports/739991.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '75036',
#               'Lab No': '7021/20',
#               'Sex': 'M',
#               'Age': '41',
#               'report_file': 'medical_reports/750361.pdf',
#               'Diagnosis': ['hibernoma']}),
#  defaultdict(list,
#              {'Patient': '750248',
#               'Lab No': '7822/20',
#               'Sex': 'F',
#               'Age': '44',
#               'report_file': 'medical_reports/750248.jpg',
#               'Diagnosis': ['adenosarcoma']}),
#  defaultdict(list,
#              {'Sex': 'F',
#               'Age': '40',
#               'Grade': '2',
#               'Patient': 'unknown',
#               'report_file': 'medical_reports/unknown.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '752503',
#               'Lab No': '8365/20',
#               'Sex': 'F',
#               'Age': '32',
#               'report_file': 'medical_reports/752503.jpg',
#               'Diagnosis': ['endometriosis']}),
#  defaultdict(list,
#              {'Patient': '747281',
#               'Lab No': '4610 20',
#               'Sex': 'F',
#               'Age': '44',
#               'report_file': 'medical_reports/747281.jpg',
#               'Diagnosis': [' dermatofibrosarcoma protuberans']}),
#  defaultdict(list,
#              {'Patient': '748808',
#               'Lab No': '6907/20',
#               'Sex': 'F',
#               'Age': '85',
#               'report_file': 'medical_reports/748808.pdf',
#               'Diagnosis': ['angiosarcoma']}),
#  defaultdict(list,
#              {'Patient': '748001',
#               'Lab No': '6356/20',
#               'Sex': 'F',
#               'Age': '64',
#               'report_file': 'medical_reports/748001.pdf',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '741861',
#               'Lab No': '0858/20',
#               'Sex': 'F',
#               'Age': '44',
#               'Grade': '2',
#               'report_file': 'medical_reports/741861.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '732874',
#               'Lab No': '5625/19',
#               'Sex': 'F',
#               'Age': '46',
#               'report_file': 'medical_reports/732874.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '753196',
#               'Lab No': '9264/20',
#               'Sex': 'F',
#               'Age': '81',
#               'Grade': '1',
#               'report_file': 'medical_reports/753196.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '4109621151',
#               'Lab No': '7006/20',
#               'Sex': 'F',
#               'Age': '80',
#               'Grade': '2',
#               'report_file': 'medical_reports/4109621151.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '524564',
#               'Lab No': '8797/20',
#               'Sex': 'M',
#               'Age': '59',
#               'Grade': '2',
#               'report_file': 'medical_reports/524564.jpg',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '726249',
#               'Lab No': '6790/20',
#               'Sex': 'M',
#               'Age': '81',
#               'Grade': '2',
#               'report_file': 'medical_reports/726249.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '570034',
#               'Lab No': '1549 57',
#               'Sex': 'M',
#               'Age': '66',
#               'report_file': 'medical_reports/570034.jpg'}),
#  defaultdict(list,
#              {'Patient': '692634',
#               'Lab No': '0476/20',
#               'Sex': 'F',
#               'Age': '56',
#               'report_file': 'medical_reports/692634.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '559279',
#               'Lab No': '6998/20',
#               'Sex': 'F',
#               'Age': '46',
#               'Grade': '2',
#               'report_file': 'medical_reports/559279.pdf'}),
#  defaultdict(list,
#              {'Patient': '751062',
#               'Lab No': '7046/20',
#               'Sex': 'M',
#               'Age': '90',
#               'Grade': '3',
#               'report_file': 'medical_reports/751062.pdf',
#               'Diagnosis': ['pleomorphic dermal sarcoma']}),
#  defaultdict(list,
#              {'Patient': '746534',
#               'Lab No': '5281 20',
#               'Sex': 'F',
#               'Age': '55',
#               'report_file': 'medical_reports/746534.pdf',
#               'Diagnosis': [' myxoid liposarcoma']}),
#  defaultdict(list,
#              {'Patient': 'M88303',
#               'Lab No': '6145/20',
#               'Sex': 'M',
#               'Age': '66',
#               'Grade': '3',
#               'report_file': 'medical_reports/749380.pdf',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '551466',
#               'Lab No': '8618/20',
#               'Sex': 'M',
#               'Age': '53',
#               'report_file': 'medical_reports/551466.jpg',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '740160',
#               'Lab No': '5013 20',
#               'Sex': 'f',
#               'Age': '82',
#               'Grade': '2',
#               'report_file': 'medical_reports/740160.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749968',
#               'Lab No': '8210/20',
#               'Sex': 'M',
#               'Age': '36',
#               'report_file': 'medical_reports/749968.jpg',
#               'Diagnosis': ['leiomyoma']}),
#  defaultdict(list,
#              {'Patient': '519535',
#               'Lab No': '1770/20',
#               'Sex': 'f',
#               'Age': '86',
#               'report_file': 'medical_reports/519535.pdf',
#               'Diagnosis': [' myxoid liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '751516',
#               'Lab No': '7609/20',
#               'Sex': 'M',
#               'Age': '82',
#               'Grade': '3',
#               'report_file': 'medical_reports/751516.jpg'}),
#  defaultdict(list,
#              {'Patient': '20741727',
#               'Lab No': '6298/20',
#               'Sex': 'M',
#               'Age': '75',
#               'report_file': 'medical_reports/20741727.pdf',
#               'Diagnosis': [' pleomorphic liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '381305',
#               'Lab No': '8121/20',
#               'Sex': 'F',
#               'Age': '56',
#               'report_file': 'medical_reports/381305.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '742419',
#               'Lab No': '0455/20',
#               'Sex': 'M',
#               'Age': '48',
#               'report_file': 'medical_reports/742419.pdf',
#               'Diagnosis': ['adenoid cystic carcinoma']}),
#  defaultdict(list,
#              {'Patient': '746505',
#               'Lab No': '4141 20',
#               'Sex': 'M',
#               'Age': '59',
#               'Grade': '2',
#               'report_file': 'medical_reports/746505.jpg',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '725466',
#               'Lab No': '9620/19',
#               'Sex': 'F',
#               'Age': '30',
#               'report_file': 'medical_reports/725466.jpg',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '742590',
#               'Lab No': '1193 20',
#               'Sex': 'M',
#               'Age': '55',
#               'report_file': 'medical_reports/742590.pdf',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '742429',
#               'Lab No': '3064 20',
#               'Sex': 'F',
#               'Age': '83',
#               'report_file': 'medical_reports/742429.pdf',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '748831',
#               'Lab No': '6197/20',
#               'Sex': 'F',
#               'Age': '75',
#               'Grade': '2',
#               'report_file': 'medical_reports/748831.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '741797',
#               'Lab No': '4182 20',
#               'Sex': 'M',
#               'Age': '50',
#               'Grade': '2',
#               'report_file': 'medical_reports/741797.jpg',
#               'Diagnosis': [' dedifferentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '752659',
#               'Lab No': '8368/20',
#               'Sex': 'M',
#               'Age': '90',
#               'Grade': '3',
#               'report_file': 'medical_reports/752659.jpg',
#               'Diagnosis': ['pleomorphic dermal sarcoma']}),
#  defaultdict(list,
#              {'Patient': '650958',
#               'Lab No': '1246/20',
#               'Sex': 'm',
#               'Age': '58',
#               'Grade': '1',
#               'report_file': 'medical_reports/650958.pdf',
#               'Diagnosis': [' myxoid liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '741021',
#               'Lab No': '2096/20',
#               'Sex': 'M',
#               'Age': '49',
#               'report_file': 'medical_reports/741021.jpg',
#               'Diagnosis': [' low-grade fibromyxoid sarcoma']}),
#  defaultdict(list,
#              {'Patient': '738175',
#               'Lab No': '3628/20',
#               'Sex': 'F',
#               'Age': '39',
#               'Grade': '2',
#               'report_file': 'medical_reports/738175.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '617727',
#               'Lab No': '5458 20',
#               'Sex': 'F',
#               'Age': '83',
#               'report_file': 'medical_reports/617727.jpg',
#               'Diagnosis': ['angiosarcoma']}),
#  defaultdict(list,
#              {'Patient': '738247',
#               'Lab No': '3463/20',
#               'Sex': 'F',
#               'Age': '77',
#               'report_file': 'medical_reports/738247.jpg',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '748278',
#               'Lab No': '5530 20',
#               'Sex': 'F',
#               'Age': '43',
#               'report_file': 'medical_reports/748278.jpg',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '750186',
#               'Lab No': '8449/20',
#               'Sex': 'M',
#               'Age': '44',
#               'report_file': 'medical_reports/750186.jpg',
#               'Diagnosis': ['leiomyoma']}),
#  defaultdict(list,
#              {'Patient': '745215',
#               'Lab No': '3240 20',
#               'Sex': 'F',
#               'Age': '57',
#               'Grade': '3',
#               'report_file': 'medical_reports/745215.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '741071',
#               'Lab No': '0387/20',
#               'Sex': 'F',
#               'Age': '44',
#               'report_file': 'medical_reports/741071.pdf',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '745101',
#               'Lab No': '3948 20',
#               'Sex': 'M',
#               'Age': '77',
#               'report_file': 'medical_reports/745101.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '742763',
#               'Lab No': '0800/20',
#               'Sex': 'F',
#               'Age': '76',
#               'Grade': '1',
#               'report_file': 'medical_reports/742763.pdf'}),
#  defaultdict(list,
#              {'Patient': 'M88903',
#               'Lab No': '6892/20',
#               'Sex': 'M',
#               'Age': '81',
#               'Grade': '2',
#               'report_file': 'medical_reports/751013.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '749887',
#               'Lab No': '8724/20',
#               'Sex': 'M',
#               'Age': '28',
#               'report_file': 'medical_reports/749887.jpg',
#               'Diagnosis': ['chondroid lipoma']}),
#  defaultdict(list,
#              {'Patient': '748127',
#               'Lab No': '5855/20',
#               'Sex': 'M',
#               'Age': '56',
#               'Grade': '3',
#               'report_file': 'medical_reports/748127.pdf'}),
#  defaultdict(list,
#              {'Patient': '6129041934',
#               'Lab No': '8919/20',
#               'Sex': 'F',
#               'Age': '50',
#               'report_file': 'medical_reports/6129041934.jpg'}),
#  defaultdict(list,
#              {'Patient': '746297',
#               'Lab No': '3924 20',
#               'Sex': 'M',
#               'Age': '76',
#               'Grade': '2',
#               'report_file': 'medical_reports/746297.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '728484',
#               'Lab No': '8376/20',
#               'Sex': 'M',
#               'Age': '38',
#               'report_file': 'medical_reports/728484.jpg',
#               'Diagnosis': ['gastrointestinal stromal tumor']}),
#  defaultdict(list,
#              {'Patient': '731785',
#               'Lab No': '4303 20',
#               'Sex': 'F',
#               'Age': '50',
#               'report_file': 'medical_reports/731785.jpg',
#               'Diagnosis': ['synovial sarcoma']}),
#  defaultdict(list,
#              {'Patient': '735988',
#               'Lab No': '5234 20',
#               'Sex': 'M',
#               'Age': '30',
#               'report_file': 'medical_reports/735988.pdf',
#               'Diagnosis': ['angiosarcoma']}),
#  defaultdict(list,
#              {'Patient': '646260',
#               'Lab No': '7639/20',
#               'Sex': 'F',
#               'Age': '52',
#               'report_file': 'medical_reports/646260.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '1440201465',
#               'Lab No': '0488/20',
#               'Sex': 'F',
#               'Age': '53',
#               'report_file': 'medical_reports/1440201465.pdf',
#               'Diagnosis': ['leiomyoma']}),
#  defaultdict(list,
#              {'Patient': '741422',
#               'Lab No': '6843/20',
#               'Sex': 'M',
#               'Age': '86',
#               'Grade': '3',
#               'report_file': 'medical_reports/741422.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '740086',
#               'Lab No': '1247 20',
#               'Sex': 'm',
#               'Age': '41',
#               'report_file': 'medical_reports/740086.pdf',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '751381',
#               'Lab No': '7494/20',
#               'Sex': 'F',
#               'Age': '62',
#               'report_file': 'medical_reports/751381.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '750844',
#               'Lab No': '8512/20',
#               'Sex': 'F',
#               'Age': '56',
#               'Grade': '3',
#               'report_file': 'medical_reports/750844.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '741054',
#               'Lab No': '0293/20',
#               'Sex': 'F',
#               'Age': '65',
#               'report_file': 'medical_reports/741054.pdf',
#               'Diagnosis': ['chondrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '742225',
#               'Lab No': '8174/20',
#               'Sex': 'M',
#               'Age': '56',
#               'report_file': 'medical_reports/742225.jpg',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '616826',
#               'Lab No': '5286/13',
#               'Sex': 'M',
#               'Age': '45',
#               'report_file': 'medical_reports/616826.pdf',
#               'Diagnosis': ['gastrointestinal stromal tumour']}),
#  defaultdict(list,
#              {'Patient': '735888',
#               'Lab No': '3514/20',
#               'Sex': 'F',
#               'Age': '56',
#               'Grade': '2',
#               'report_file': 'medical_reports/735888.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '635102',
#               'Lab No': '8687/20',
#               'Sex': 'M',
#               'Age': '43',
#               'report_file': 'medical_reports/635102.jpg',
#               'Diagnosis': ['gastrointestinal stromal tumor']}),
#  defaultdict(list,
#              {'Patient': '752434',
#               'Lab No': '9104/20',
#               'Sex': 'M',
#               'Age': '62',
#               'report_file': 'medical_reports/752434.jpg',
#               'Diagnosis': ['fibrolipoma']}),
#  defaultdict(list,
#              {'Patient': '751024',
#               'Lab No': '8166/20',
#               'Sex': 'M',
#               'Age': '90',
#               'Grade': '3',
#               'report_file': 'medical_reports/751024.jpg'}),
#  defaultdict(list,
#              {'Patient': '753071',
#               'Lab No': '8907/20',
#               'Sex': 'M',
#               'Age': '71',
#               'Grade': '3',
#               'report_file': 'medical_reports/753071.jpg',
#               'Diagnosis': [' pleomorphic rhabdomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '740069',
#               'Lab No': '1749 20',
#               'Sex': 'M',
#               'Age': '28',
#               'report_file': 'medical_reports/740069.pdf'}),
#  defaultdict(list,
#              {'Patient': '380574',
#               'Lab No': '1357 20',
#               'Sex': 'M',
#               'Age': '73',
#               'Grade': '2',
#               'report_file': 'medical_reports/380574.pdf',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '741709',
#               'Lab No': '2937 20',
#               'Sex': 'F',
#               'Age': '34',
#               'report_file': 'medical_reports/741709.pdf',
#               'Diagnosis': [' low-grade fibromyxoid sarcoma']}),
#  defaultdict(list,
#              {'Patient': '380073',
#               'Lab No': '8125/20',
#               'Sex': 'M',
#               'Age': '19',
#               'report_file': 'medical_reports/380073.jpg',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '741550',
#               'Lab No': '4142 20',
#               'Sex': 'F',
#               'Age': '71',
#               'Grade': '2',
#               'report_file': 'medical_reports/741550.jpg',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '6261275661',
#               'Lab No': '3851/20',
#               'Sex': 'M',
#               'Age': '52',
#               'report_file': 'medical_reports/6261275661.jpg',
#               'Diagnosis': [' myxoid liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '745029',
#               'Lab No': '2456 20',
#               'Sex': 'F',
#               'Age': '35',
#               'report_file': 'medical_reports/745029.pdf',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '736152',
#               'Lab No': '7715/20',
#               'Sex': 'M',
#               'Age': '85',
#               'report_file': 'medical_reports/736152.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '697097',
#               'Lab No': '5228 20',
#               'Sex': 'f',
#               'Age': '70',
#               'Grade': '2',
#               'report_file': 'medical_reports/697097.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '750835',
#               'Lab No': '8410/20',
#               'Sex': 'M',
#               'Age': '39',
#               'Grade': '1',
#               'report_file': 'medical_reports/750835.jpg',
#               'Diagnosis': ['smooth muscle neoplasm']}),
#  defaultdict(list,
#              {'Patient': '720934',
#               'Lab No': '5450 20',
#               'Sex': 'M',
#               'Age': '88',
#               'Grade': '3',
#               'report_file': 'medical_reports/720934.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749805',
#               'Lab No': '6693/20',
#               'Sex': 'M',
#               'Age': '43',
#               'report_file': 'medical_reports/749805.pdf'}),
#  defaultdict(list,
#              {'Patient': '729483',
#               'Lab No': '1120 20',
#               'Sex': 'F',
#               'Age': '57',
#               'report_file': 'medical_reports/729483.pdf',
#               'Diagnosis': ['gist']}),
#  defaultdict(list,
#              {'Patient': '594889',
#               'Lab No': '1276 20',
#               'Sex': 'M',
#               'Age': '81',
#               'report_file': 'medical_reports/594889.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '742405',
#               'Lab No': '1629 20',
#               'Sex': 'M',
#               'Age': '77',
#               'Grade': '2',
#               'report_file': 'medical_reports/742405.jpg',
#               'Diagnosis': [' dedifferentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '746704',
#               'Lab No': '5307 20',
#               'Sex': 'M',
#               'Age': '60',
#               'report_file': 'medical_reports/746704.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '739990',
#               'Lab No': '0657/20',
#               'Sex': 'F',
#               'Age': '55',
#               'report_file': 'medical_reports/739990.pdf',
#               'Diagnosis': ['dermatofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '741276',
#               'Lab No': '2391 20',
#               'Sex': 'F',
#               'Age': '82',
#               'Grade': '2',
#               'report_file': 'medical_reports/741276.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '744246',
#               'Lab No': '4506 20',
#               'Sex': 'M',
#               'Age': '69',
#               'report_file': 'medical_reports/744246.jpg',
#               'Diagnosis': ['gist']}),
#  defaultdict(list,
#              {'Patient': '746397',
#               'Lab No': '8679/20',
#               'Sex': 'F',
#               'Age': '56',
#               'report_file': 'medical_reports/746397.jpg',
#               'Diagnosis': ['fibrolipoma']}),
#  defaultdict(list,
#              {'Patient': '742494',
#               'Lab No': '2324/20',
#               'Sex': 'M',
#               'Age': '60',
#               'report_file': 'medical_reports/742494.pdf',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '731349',
#               'Lab No': '3934/19',
#               'Sex': 'F',
#               'Age': '74',
#               'report_file': 'medical_reports/731349.pdf',
#               'Diagnosis': ['gastrointestinal stromal tumour']}),
#  defaultdict(list,
#              {'Patient': '752662',
#               'Lab No': '8768/20',
#               'Sex': 'F',
#               'Age': '61',
#               'report_file': 'medical_reports/752662.jpg'}),
#  defaultdict(list,
#              {'Patient': '746406',
#               'Lab No': '3631 20',
#               'Sex': 'F',
#               'Age': '64',
#               'Grade': '2',
#               'report_file': 'medical_reports/746406.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '630043',
#               'Lab No': '2320/14',
#               'Sex': 'M',
#               'Age': '80',
#               'Grade': '2',
#               'report_file': 'medical_reports/630043.pdf',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '746526',
#               'Lab No': '4326 20',
#               'Sex': 'F',
#               'Age': '82',
#               'report_file': 'medical_reports/746526_2.jpg'}),
#  defaultdict(list,
#              {'Patient': '748849',
#               'Lab No': '7306/20',
#               'Sex': 'M',
#               'Age': '66',
#               'report_file': 'medical_reports/748849.jpg',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '739986',
#               'Sex': 'F',
#               'Age': '79',
#               'Grade': '3',
#               'report_file': 'medical_reports/739986.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749843',
#               'Lab No': '8122/20',
#               'Sex': 'M',
#               'Age': '72',
#               'report_file': 'medical_reports/749843.jpg',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '747969',
#               'Lab No': '4960 20',
#               'Sex': 'M',
#               'Age': '69',
#               'Grade': '2',
#               'report_file': 'medical_reports/747969.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '746641',
#               'Lab No': '4857 20',
#               'Sex': 'F',
#               'Age': '35',
#               'Grade': '3',
#               'report_file': 'medical_reports/746641.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749432',
#               'Lab No': '6276/20',
#               'Sex': 'M',
#               'Age': '75',
#               'Grade': '3',
#               'report_file': 'medical_reports/749432.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '750115',
#               'Lab No': '6844/20',
#               'Sex': 'M',
#               'Age': '21',
#               'Grade': '3',
#               'report_file': 'medical_reports/750115.pdf',
#               'Diagnosis': ['dermatofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '7080630150',
#               'Lab No': '6280/20',
#               'Sex': 'F',
#               'Age': '52',
#               'report_file': 'medical_reports/7080630150.pdf',
#               'Diagnosis': ['intramuscular myxoma']}),
#  defaultdict(list,
#              {'Patient': '680138',
#               'Lab No': '3757 20',
#               'report_file': 'medical_reports/680138.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '744153',
#               'Lab No': '1922/20',
#               'Sex': 'F',
#               'Age': '57',
#               'Grade': '3',
#               'report_file': 'medical_reports/744153.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '665253',
#               'Lab No': '8308/20',
#               'Sex': 'F',
#               'Age': '79',
#               'Grade': '1',
#               'report_file': 'medical_reports/665253.jpg'}),
#  defaultdict(list,
#              {'Patient': '742620',
#               'Lab No': '1714 20',
#               'Sex': 'm',
#               'Age': '43',
#               'report_file': 'medical_reports/742620.pdf',
#               'Diagnosis': [' dermatofibrosarcoma protuberans']}),
#  defaultdict(list,
#              {'Patient': '750828',
#               'Lab No': '8221/20',
#               'Sex': 'M',
#               'Age': '54',
#               'report_file': 'medical_reports/750828.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': 'H14404',
#               'Lab No': '1444/20',
#               'Sex': 'M',
#               'Age': '59',
#               'report_file': 'medical_reports/H14404.pdf'}),
#  defaultdict(list,
#              {'Patient': '752433',
#               'Lab No': '8046/20',
#               'Sex': 'M',
#               'Age': '63',
#               'report_file': 'medical_reports/752433.jpg',
#               'Diagnosis': ['intramuscular myxoma']}),
#  defaultdict(list,
#              {'Patient': '393265',
#               'Lab No': '8675/20',
#               'Sex': 'F',
#               'Age': '75',
#               'report_file': 'medical_reports/393265.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '746577',
#               'Lab No': '4138 20',
#               'Sex': 'M',
#               'Age': '67',
#               'Grade': '2',
#               'report_file': 'medical_reports/746577.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '627427',
#               'Lab No': '5278 20',
#               'Sex': 'F',
#               'Age': '73',
#               'Grade': '2',
#               'report_file': 'medical_reports/627427.pdf',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '732930',
#               'Lab No': '4179 20',
#               'Sex': 'F',
#               'Age': '58',
#               'report_file': 'medical_reports/732930.jpg',
#               'Diagnosis': ['epithelioid hemangioendothelioma']}),
#  defaultdict(list,
#              {'Patient': '698711',
#               'Lab No': '1984 20',
#               'Sex': 'M',
#               'Age': '67',
#               'report_file': 'medical_reports/698711.pdf'}),
#  defaultdict(list,
#              {'Patient': '373805',
#               'Lab No': '6069/20',
#               'Sex': 'M',
#               'Age': '65',
#               'Grade': '2',
#               'report_file': 'medical_reports/373805.pdf',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': 'M89313',
#               'Lab No': '7065/20',
#               'Sex': 'F',
#               'Age': '38',
#               'report_file': 'medical_reports/548844.pdf'}),
#  defaultdict(list,
#              {'Patient': '740197',
#               'Lab No': '0628/20',
#               'Sex': 'F',
#               'Age': '32',
#               'report_file': 'medical_reports/740197.pdf',
#               'Diagnosis': [' clear cell sarcoma of soft tissue']}),
#  defaultdict(list,
#              {'Patient': '741269',
#               'Lab No': '1195 20',
#               'Sex': 'M',
#               'Age': '58',
#               'report_file': 'medical_reports/741269.pdf',
#               'Diagnosis': [' solitary fibrous tumour']}),
#  defaultdict(list,
#              {'Patient': '721973',
#               'Lab No': '1570 20',
#               'Sex': 'F',
#               'Age': '13',
#               'report_file': 'medical_reports/721973.pdf',
#               'Diagnosis': ['neuroblastoma']}),
#  defaultdict(list,
#              {'Patient': '4567206215',
#               'Lab No': '1290/20',
#               'Sex': 'F',
#               'Age': '62',
#               'Grade': '2',
#               'report_file': 'medical_reports/4567206215.pdf'}),
#  defaultdict(list,
#              {'Patient': '732603',
#               'Lab No': '1339 20',
#               'Sex': 'F',
#               'Age': '62',
#               'Grade': '2',
#               'report_file': 'medical_reports/732603.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '751975',
#               'Lab No': '8037/20',
#               'Sex': 'M',
#               'Age': '11',
#               'report_file': 'medical_reports/751975.jpg',
#               'Diagnosis': ['neurofibroma']}),
#  defaultdict(list,
#              {'Patient': '728324',
#               'Sex': 'M',
#               'Age': '46',
#               'report_file': 'medical_reports/728324.pdf',
#               'Diagnosis': ['uncertain']}),
#  defaultdict(list,
#              {'Patient': '753076',
#               'Lab No': '8779/20',
#               'Sex': 'F',
#               'Age': '59',
#               'Grade': '1',
#               'report_file': 'medical_reports/753076.jpg',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '750907',
#               'Lab No': '8086/20',
#               'Sex': 'F',
#               'Age': '48',
#               'report_file': 'medical_reports/750907.jpg',
#               'Diagnosis': ['myxoma']}),
#  defaultdict(list,
#              {'Patient': '748804',
#               'Lab No': '6555/20',
#               'Sex': 'M',
#               'Age': '50',
#               'Grade': '3',
#               'report_file': 'medical_reports/748804.pdf',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '4108091108',
#               'Lab No': '2099 20',
#               'Sex': 'F',
#               'Age': '78',
#               'report_file': 'medical_reports/4108091108.pdf',
#               'Diagnosis': ['angiosarcoma']}),
#  defaultdict(list,
#              {'Patient': '4060999490',
#               'Lab No': '1989 20',
#               'Sex': 'm',
#               'Age': '45',
#               'Grade': '2',
#               'report_file': 'medical_reports/4060999490.pdf',
#               'Diagnosis': ['spindle cell lipoma']}),
#  defaultdict(list,
#              {'Patient': '745512',
#               'Lab No': '3571 20',
#               'Sex': 'F',
#               'Age': '31',
#               'report_file': 'medical_reports/745512.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '733266',
#               'Lab No': '1143 20',
#               'Sex': 'F',
#               'Age': '73',
#               'report_file': 'medical_reports/733266.jpg'}),
#  defaultdict(list,
#              {'Patient': '742663',
#               'Lab No': '0487/20',
#               'Sex': 'F',
#               'Age': '64',
#               'report_file': 'medical_reports/742663.pdf',
#               'Diagnosis': ['gastrointestinal stromal tumour']}),
#  defaultdict(list,
#              {'Patient': '740425',
#               'Lab No': '6499/19',
#               'Sex': 'M',
#               'Age': '78',
#               'Grade': '1',
#               'report_file': 'medical_reports/740425.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '751380',
#               'Lab No': '7495/20',
#               'Sex': 'M',
#               'Age': '38',
#               'report_file': 'medical_reports/751380.jpg',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '747179',
#               'Lab No': '3949 20',
#               'Sex': 'F',
#               'Age': '71',
#               'Grade': '2',
#               'report_file': 'medical_reports/747179.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '746848',
#               'Lab No': '4100 20',
#               'Sex': 'M',
#               'Age': '57',
#               'report_file': 'medical_reports/746848.jpg',
#               'Diagnosis': ['spindle cell lipoma']}),
#  defaultdict(list,
#              {'Patient': '750077',
#               'Lab No': '7405/20',
#               'Sex': 'M',
#               'Age': '45',
#               'report_file': 'medical_reports/750077.jpg',
#               'Diagnosis': ['ganglioneuroma']}),
#  defaultdict(list,
#              {'Patient': '711086',
#               'Lab No': '0432/20',
#               'Sex': 'M',
#               'Grade': '2',
#               'report_file': 'medical_reports/711086.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '749042',
#               'Lab No': '5992/20',
#               'Sex': 'M',
#               'Age': '22',
#               'report_file': 'medical_reports/749042.pdf',
#               'Diagnosis': ['dermatofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '732812',
#               'Lab No': '0587/20',
#               'Sex': 'M',
#               'Age': '68',
#               'Grade': '3',
#               'report_file': 'medical_reports/732812.pdf',
#               'Diagnosis': [' dedifferentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '746454',
#               'Lab No': '4063 20',
#               'Sex': 'F',
#               'Age': '80',
#               'report_file': 'medical_reports/746454.jpg',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '747026',
#               'Lab No': '4591 20',
#               'Sex': 'F',
#               'Age': '55',
#               'report_file': 'medical_reports/747026.jpg',
#               'Diagnosis': ['granular cell tumor']}),
#  defaultdict(list,
#              {'Patient': '729823',
#               'Lab No': '8394/20',
#               'Sex': 'F',
#               'Age': '65',
#               'report_file': 'medical_reports/729823.jpg',
#               'Diagnosis': ['gastrointestinal stromal tumor']}),
#  defaultdict(list,
#              {'Patient': '743965',
#               'Lab No': '2891/20',
#               'Sex': 'M',
#               'Age': '72',
#               'report_file': 'medical_reports/743965.pdf',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '747375',
#               'Lab No': '4551 20',
#               'Sex': 'M',
#               'Age': '89',
#               'Grade': '2',
#               'report_file': 'medical_reports/747375.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '14578',
#               'Lab No': '4578 19',
#               'Sex': 'M',
#               'Age': '79',
#               'report_file': 'medical_reports/725910.jpg',
#               'Diagnosis': ['fibrosis']}),
#  defaultdict(list,
#              {'Patient': '4688493924',
#               'Lab No': '2293 20',
#               'Sex': 'F',
#               'Age': '36',
#               'report_file': 'medical_reports/4688493924.pdf'}),
#  defaultdict(list,
#              {'Patient': '739357',
#               'Lab No': '7928/20',
#               'Sex': 'M',
#               'Age': '18',
#               'report_file': 'medical_reports/739357.jpg'}),
#  defaultdict(list,
#              {'Patient': '749217',
# ...
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '752457',
#               'Lab No': '8045/20',
#               'Sex': 'M',
#               'Age': '27',
#               'report_file': 'medical_reports/752457.jpg',
#               'Diagnosis': ['spindle cell lipoma']}),
#  defaultdict(list,
#              {'Patient': '746525',
#               'Lab No': '7371/20',
#               'Sex': 'F',
#               'Age': '31',
#               'report_file': 'medical_reports/746525.jpg',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Sex': 'F',
#               'Age': '2',
#               'Patient': '740913',
#               'report_file': 'medical_reports/740913.pdf',
#               'Diagnosis': ['ganglioneuroma']}),
#  defaultdict(list,
#              {'Patient': '11420',
#               'Lab No': '6689/20',
#               'Sex': 'F',
#               'Age': '85',
#               'Grade': '1',
#               'report_file': 'medical_reports/751095.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '714203',
#               'Lab No': '3825/20',
#               'Sex': 'F',
#               'Age': '18',
#               'report_file': 'medical_reports/714203.pdf',
#               'Diagnosis': ['uncertain']}),
#  defaultdict(list,
#              {'Patient': '739357',
#               'Lab No': '7928/20',
#               'Sex': 'M',
#               'Age': '18',
#               'report_file': 'medical_reports/739537.jpg',
#               'Diagnosis': [' angiomatoid fibrous histiocytoma']}),
#  defaultdict(list,
#              {'Patient': '703664',
#               'Lab No': '8415/20',
#               'Sex': 'F',
#               'Grade': '2',
#               'report_file': 'medical_reports/703664.jpg',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '4683550008',
#               'Lab No': '4541/19',
#               'Sex': 'F',
#               'Age': '47',
#               'report_file': 'medical_reports/4683550008.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '749963',
#               'Lab No': '7934/20',
#               'Sex': 'M',
#               'Age': '49',
#               'report_file': 'medical_reports/749963.jpg',
#               'Diagnosis': ['intramuscular myxoma']}),
#  defaultdict(list,
#              {'Patient': '746364',
#               'Lab No': '4437 20',
#               'Sex': 'F',
#               'Age': '57',
#               'report_file': 'medical_reports/746364.pdf',
#               'Diagnosis': ['smooth muscle tumor']}),
#  defaultdict(list,
#              {'Patient': '741773',
#               'Lab No': '4590 20',
#               'Sex': 'M',
#               'Age': '44',
#               'report_file': 'medical_reports/741773.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '752587',
#               'Lab No': '9099/20',
#               'Sex': 'F',
#               'Age': '85',
#               'report_file': 'medical_reports/752587.jpg',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '740385',
#               'Lab No': '1719 20',
#               'Sex': 'F',
#               'Age': '47',
#               'report_file': 'medical_reports/740385.pdf',
#               'Diagnosis': [' solitary fibrous tumour']}),
#  defaultdict(list,
#              {'Patient': '741850',
#               'Lab No': '9373/20',
#               'Sex': 'F',
#               'Age': '43',
#               'report_file': 'medical_reports/741850.jpg',
#               'Diagnosis': ['lipoma']}),
#  defaultdict(list,
#              {'Patient': '742348',
#               'Lab No': '0526/20',
#               'Sex': 'F',
#               'Age': '65',
#               'Grade': '1',
#               'report_file': 'medical_reports/742348.pdf',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '742095',
#               'Lab No': '4504/20',
#               'Sex': 'F',
#               'Age': '46',
#               'report_file': 'medical_reports/742095.jpg',
#               'Diagnosis': ['angiosarcoma']}),
#  defaultdict(list,
#              {'Patient': '625410',
#               'Lab No': '6071/20',
#               'Sex': 'M',
#               'Age': '78',
#               'Grade': '1',
#               'report_file': 'medical_reports/625410.pdf',
#               'Diagnosis': [' myxofibrosarcoma']}),
#  defaultdict(list,
#              {'Patient': '745153',
#               'Lab No': '7372/20',
#               'Sex': 'M',
#               'Age': '74',
#               'report_file': 'medical_reports/745153.jpg',
#               'Diagnosis': ['gastrointestinal stromal tumor']}),
#  defaultdict(list,
#              {'Patient': '750804',
#               'Lab No': '8806/20',
#               'Sex': 'F',
#               'Age': '60',
#               'report_file': 'medical_reports/750804.jpg',
#               'Diagnosis': ['myofibroblastoma']}),
#  defaultdict(list,
#              {'Patient': '751030',
#               'Lab No': '6894/20',
#               'Sex': 'F',
#               'Age': '56',
#               'Grade': '3',
#               'report_file': 'medical_reports/751030.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '748836',
#               'Lab No': '6692 20',
#               'Sex': 'f',
#               'Age': '30',
#               'report_file': 'medical_reports/748836.pdf',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '740255',
#               'Lab No': '3143/20',
#               'Sex': 'F',
#               'Age': '29',
#               'report_file': 'medical_reports/740255.jpg',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '746527',
#               'Lab No': '4155 20',
#               'Sex': 'F',
#               'Age': '78',
#               'Grade': '3',
#               'report_file': 'medical_reports/746527.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '746726',
#               'Lab No': '6799/20',
#               'Sex': 'M',
#               'Age': '77',
#               'Grade': '3',
#               'report_file': 'medical_reports/746726.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '728569',
#               'Lab No': '3459/20',
#               'Sex': 'M',
#               'Age': '93',
#               'Grade': '3',
#               'report_file': 'medical_reports/728569.pdf'}),
#  defaultdict(list,
#              {'Patient': '721973',
#               'Lab No': '4281 20',
#               'Sex': 'F',
#               'Age': '14',
#               'report_file': 'medical_reports/721973.jpg',
#               'Diagnosis': ['neuroblastoma']}),
#  defaultdict(list,
#              {'Patient': '749888',
#               'Lab No': '7673/20',
#               'Sex': 'M',
#               'Age': '57',
#               'Grade': '1',
#               'report_file': 'medical_reports/749888.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '749971',
#               'Lab No': '6759/20',
#               'Sex': 'M',
#               'Age': '38',
#               'Grade': '2',
#               'report_file': 'medical_reports/749971.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '741545',
#               'Lab No': '2434/20',
#               'Sex': 'F',
#               'Age': '55',
#               'Grade': '1',
#               'report_file': 'medical_reports/741545.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '745192',
#               'Lab No': '3498 20',
#               'Sex': 'M',
#               'Age': '80',
#               'Grade': '3',
#               'report_file': 'medical_reports/745192.jpg',
#               'Diagnosis': [' pleomorphic rhabdomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '752415',
#               'Lab No': '8124/20',
#               'Sex': 'M',
#               'Age': '43',
#               'report_file': 'medical_reports/752415.jpg',
#               'Diagnosis': ['neurofibroma']}),
#  defaultdict(list,
#              {'Patient': '749815',
#               'Lab No': '6955/20',
#               'Sex': 'F',
#               'Age': '73',
#               'report_file': 'medical_reports/749815.pdf'}),
#  defaultdict(list,
#              {'Patient': '743474',
#               'Lab No': '1593/20',
#               'Sex': 'F',
#               'Age': '40',
#               'report_file': 'medical_reports/743474.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': 'M88903',
#               'Lab No': '6352/20',
#               'Sex': 'F',
#               'Age': '76',
#               'Grade': '3',
#               'report_file': 'medical_reports/747850.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '747140',
#               'Lab No': '4505 20',
#               'Sex': 'F',
#               'Age': '56',
#               'report_file': 'medical_reports/747140.jpg',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '750216',
#               'Lab No': '7933/20',
#               'Sex': 'M',
#               'Age': '72',
#               'Grade': '3',
#               'report_file': 'medical_reports/750216.jpg',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '648037',
#               'Lab No': '8493/20',
#               'Sex': 'M',
#               'Age': '74',
#               'report_file': 'medical_reports/648037.jpg',
#               'Diagnosis': ['melanoma']}),
#  defaultdict(list,
#              {'Patient': '744378',
#               'Lab No': '3945 20',
#               'Sex': 'F',
#               'Age': '11',
#               'report_file': 'medical_reports/744378.jpg'}),
#  defaultdict(list,
#              {'Patient': '749378',
#               'Lab No': '6314/20',
#               'Sex': 'M',
#               'Age': '65',
#               'Grade': '2',
#               'report_file': 'medical_reports/749378.pdf',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '746824',
#               'Lab No': '4105 20',
#               'Sex': 'F',
#               'Age': '52',
#               'report_file': 'medical_reports/746824.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '607460',
#               'Sex': 'F',
#               'Age': '21',
#               'Grade': '2',
#               'report_file': 'medical_reports/607460.pdf',
#               'Diagnosis': [' well-differentiated liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '741363',
#               'Lab No': '1365 20',
#               'Sex': 'M',
#               'Age': '45',
#               'Grade': '2',
#               'report_file': 'medical_reports/741363.pdf',
#               'Diagnosis': [' leiomyosarcoma']}),
#  defaultdict(list,
#              {'Patient': '736488',
#               'Sex': 'F',
#               'Age': '31',
#               'report_file': 'medical_reports/736488.pdf',
#               'Diagnosis': ['granular cell tumour']}),
#  defaultdict(list,
#              {'Patient': '741771',
#               'Lab No': '3847 20',
#               'Sex': 'F',
#               'Age': '49',
#               'report_file': 'medical_reports/741771.jpg',
#               'Diagnosis': ['myxoma']}),
#  defaultdict(list,
#              {'Patient': '748891',
#               'Lab No': '6391/20',
#               'Sex': 'M',
#               'Age': '62',
#               'report_file': 'medical_reports/748891.pdf',
#               'Diagnosis': ['fibrolipoma']}),
#  defaultdict(list,
#              {'Patient': '6250045082',
#               'Lab No': '0483 20',
#               'Sex': 'F',
#               'Age': '64',
#               'report_file': 'medical_reports/6250045082.jpg',
#               'Diagnosis': ['mammary-type myofibroblastoma']}),
#  defaultdict(list,
#              {'Patient': '740093',
#               'Lab No': '1983 20',
#               'Sex': 'F',
#               'Age': '55',
#               'report_file': 'medical_reports/740093.pdf'}),
#  defaultdict(list,
#              {'Patient': 'M88103',
#               'Lab No': '7467 14',
#               'Sex': 'F',
#               'Age': '79',
#               'Grade': '2',
#               'report_file': 'medical_reports/746714.pdf',
#               'Diagnosis': [' myxoinflammatory fibroblastic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '741711',
#               'Lab No': '3848/20',
#               'Sex': 'F',
#               'Age': '42',
#               'report_file': 'medical_reports/741711.jpg',
#               'Diagnosis': [' desmoid-type fibromatosis']}),
#  defaultdict(list,
#              {'Patient': '662198',
#               'Lab No': '2078/20',
#               'Sex': 'M',
#               'Age': '27',
#               'report_file': 'medical_reports/662198.jpg'}),
#  defaultdict(list,
#              {'Patient': '751165',
#               'Lab No': '8704/20',
#               'Sex': 'M',
#               'Age': '70',
#               'report_file': 'medical_reports/751165.jpg'}),
#  defaultdict(list,
#              {'Patient': '750216',
#               'Lab No': '6893/20',
#               'Sex': 'M',
#               'Age': '72',
#               'Grade': '3',
#               'report_file': 'medical_reports/750216.pdf',
#               'Diagnosis': ['spindle cell sarcoma']}),
#  defaultdict(list,
#              {'Patient': '4987958562',
#               'Lab No': '7851/20',
#               'Sex': 'M',
#               'Age': '31',
#               'report_file': 'medical_reports/4987958562.jpg',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '740477',
#               'Lab No': '3379 20',
#               'Sex': 'M',
#               'Age': '68',
#               'report_file': 'medical_reports/740477.jpg',
#               'Diagnosis': ['pleomorphic sarcoma']}),
#  defaultdict(list,
#              {'Patient': '747015',
#               'Lab No': '5225/20',
#               'Sex': 'F',
#               'Age': '35',
#               'report_file': 'medical_reports/747015.jpg',
#               'Diagnosis': [' myxoid liposarcoma']}),
#  defaultdict(list,
#              {'Patient': '4445753947',
#               'Lab No': '7579/20',
#               'Sex': 'M',
#               'Age': '71',
#               'report_file': 'medical_reports/4445753947.jpg',
#               'Diagnosis': ['pleomorphic lipoma']}),
#  defaultdict(list,
#              {'Patient': '745095',
#               'Lab No': '8825/20',
#               'Sex': 'M',
#               'Age': '63',
#               'report_file': 'medical_reports/745095.jpg',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '744243',
#               'Lab No': '7659/20',
#               'Sex': 'M',
#               'Age': '57',
#               'report_file': 'medical_reports/744243.jpg',
#               'Diagnosis': ['solitary fibrous tumor']}),
#  defaultdict(list,
#              {'Patient': '746770',
#               'Lab No': '4099 20',
#               'Sex': 'M',
#               'Age': '63',
#               'report_file': 'medical_reports/746770.jpg',
#               'Diagnosis': ['sarcomatoid carcinoma']}),
#  defaultdict(list,
#              {'Patient': '696401',
#               'Lab No': '1821 20',
#               'Sex': 'F',
#               'Age': '75',
#               'report_file': 'medical_reports/696401.pdf',
#               'Diagnosis': ['schwannoma']}),
#  defaultdict(list,
#              {'Patient': '736363',
#               'Lab No': '4184 20',
#               'Sex': 'M',
#               'Age': '47',
#               'report_file': 'medical_reports/736363.jpg',
#               'Diagnosis': [' myxoid liposarcoma']}),
#  defaultdict(list,
#              {'Patient': 'H28616',
#               'Lab No': '8812/20',
#               'Sex': 'M',
#               'Age': '23',
#               'report_file': 'medical_reports/H28616.jpg',
#               'Diagnosis': [' synovial sarcoma ']})]

# %%
records["Diagnosis"]=records["Diagnosis"].apply(lambda x:list(set(x)) if isinstance(x,list) else x)

records["Diagnosis"]=records["Diagnosis"].apply(lambda x:",".join(x) if isinstance(x,list) else x)

# %%
records["Diagnosis"]=records["Diagnosis"].apply(lambda x:x[0] if isinstance(x,list) else x)

# %%
records
# Out:
#      Age                               Diagnosis Grade    Lab No     Patient  \
# 0     21                                     NaN   NaN   4066 20      746516
# 1     59                          leiomyosarcoma     2   2392 20      741984
# 2     81                                fibrosis     3   8150/20      726249
# 3     68                    spindle cell sarcoma   NaN   8805/20      752384
# 4     61                              schwannoma   NaN  2180: 10      742180
# 5    NaN                                  lipoma     1   0604/20      736259
# 6    NaN                                  lipoma   NaN       NaN      737695
# 7     71                          leiomyosarcoma     3   3384/20      678367
# 8     65                        myofibroblastoma   NaN   3764 20      740278
# 9     22               desmoid-type fibromatosis   NaN   6395 20      749189
# 10    53                          leiomyosarcoma     3   1698 20      744062
# 11    61                             fibrolipoma   NaN       NaN      740690
# 12    76                                     NaN     2   8513/20      752665
# 13    34                    spindle cell sarcoma     3   7079/20      690405
# 14    55                                fibrosis   NaN   6301/20      574148
# 15    75                    spindle cell sarcoma     2   5377 20      723014
# 16    18                        rhabdomyosarcoma   NaN   3032/20      745337
# 17    44                     pleomorphic sarcoma     2   3181/20      740221
# 18    73               desmoid-type fibromatosis   NaN   8617/20      749815
# 19    47         well-differentiated liposarcoma   NaN   8551/20      667098
# 20    57                              schwannoma   NaN   4064 20      746528
# 21    73                          leiomyosarcoma     3   7756/20      751523
# 22    65                        rhabdomyosarcoma     3   7861/20      750034
# 23    71                            angiosarcoma   NaN   7546/20      749870
# 24    51                  solitary fibrous tumor   NaN   4269 20      746764
# 25    59                     pleomorphic sarcoma     3   8396/20      752349
# 26    58                           elastofibroma   NaN   6970/20      742276
# 27    71                                     NaN   NaN   5394 20      380577
# 28   NaN                          leiomyosarcoma   NaN   3468/20      731672
# 29    37                         epidermoid cyst   NaN   1280 20      740198
# ..   ...                                     ...   ...       ...         ...
# 313   40                    spindle cell sarcoma   NaN   1593/20      743474
# 314   76                          leiomyosarcoma     3   6352/20      M88903
# 315   56                          leiomyosarcoma   NaN   4505 20      747140
# 316   72                    spindle cell sarcoma     3   7933/20      750216
# 317   74                                melanoma   NaN   8493/20      648037
# 318   11                                     NaN   NaN   3945 20      744378
# 319   65                     pleomorphic sarcoma     2   6314/20      749378
# 320   52               desmoid-type fibromatosis   NaN   4105 20      746824
# 321   21         well-differentiated liposarcoma     2       NaN      607460
# 322   45                          leiomyosarcoma     2   1365 20      741363
# 323   31                    granular cell tumour   NaN       NaN      736488
# 324   49                                  myxoma   NaN   3847 20      741771
# 325   62                             fibrolipoma   NaN   6391/20      748891
# 326   64           mammary-type myofibroblastoma   NaN   0483 20  6250045082
# 327   55                                     NaN   NaN   1983 20      740093
# 328   79   myxoinflammatory fibroblastic sarcoma     2   7467 14      M88103
# 329   42               desmoid-type fibromatosis   NaN   3848/20      741711
# 330   27                                     NaN   NaN   2078/20      662198
# 331   70                                     NaN   NaN   8704/20      751165
# 332   72                    spindle cell sarcoma     3   6893/20      750216
# 333   31                              schwannoma   NaN   7851/20  4987958562
# 334   68                     pleomorphic sarcoma   NaN   3379 20      740477
# 335   35                      myxoid liposarcoma   NaN   5225/20      747015
# 336   71                      pleomorphic lipoma   NaN   7579/20  4445753947
# 337   63                  solitary fibrous tumor   NaN   8825/20      745095
# 338   57                  solitary fibrous tumor   NaN   7659/20      744243
# 339   63                   sarcomatoid carcinoma   NaN   4099 20      746770
# 340   75                              schwannoma   NaN   1821 20      696401
# 341   47                      myxoid liposarcoma   NaN   4184 20      736363
# 342   23                       synovial sarcoma    NaN   8812/20      H28616
#
#      Sex                     report_file
# 0      F      medical_reports/746516.jpg
# 1      M      medical_reports/741984.pdf
# 2      M      medical_reports/726249.jpg
# 3      M      medical_reports/752384.jpg
# 4      F      medical_reports/742180.pdf
# 5      F      medical_reports/736259.pdf
# 6    NaN      medical_reports/737695.pdf
# 7      F      medical_reports/678367.jpg
# 8      F      medical_reports/740278.jpg
# 9      F      medical_reports/749189.pdf
# 10     F      medical_reports/744062.pdf
# 11     F      medical_reports/740690.pdf
# 12     M      medical_reports/752665.jpg
# 13     M      medical_reports/690405.pdf
# 14     M      medical_reports/574148.pdf
# 15     F      medical_reports/723014.pdf
# 16     M      medical_reports/745337.pdf
# 17     M      medical_reports/740221.pdf
# 18     F      medical_reports/749815.jpg
# 19     F      medical_reports/667098.jpg
# 20     F      medical_reports/746528.jpg
# 21     M      medical_reports/751523.jpg
# 22     F      medical_reports/750034.jpg
# 23     M      medical_reports/749870.jpg
# 24     F      medical_reports/746764.jpg
# 25     F      medical_reports/752349.jpg
# 26     M      medical_reports/742276.pdf
# 27     F      medical_reports/380577.pdf
# 28     F      medical_reports/731672.pdf
# 29     M      medical_reports/740198.pdf
# ..   ...                             ...
# 313    F      medical_reports/743474.jpg
# 314    F      medical_reports/747850.pdf
# 315    F      medical_reports/747140.jpg
# 316    M      medical_reports/750216.jpg
# 317    M      medical_reports/648037.jpg
# 318    F      medical_reports/744378.jpg
# 319    M      medical_reports/749378.pdf
# 320    F      medical_reports/746824.jpg
# 321    F      medical_reports/607460.pdf
# 322    M      medical_reports/741363.pdf
# 323    F      medical_reports/736488.pdf
# 324    F      medical_reports/741771.jpg
# 325    M      medical_reports/748891.pdf
# 326    F  medical_reports/6250045082.jpg
# 327    F      medical_reports/740093.pdf
# 328    F      medical_reports/746714.pdf
# 329    F      medical_reports/741711.jpg
# 330    M      medical_reports/662198.jpg
# 331    M      medical_reports/751165.jpg
# 332    M      medical_reports/750216.pdf
# 333    M  medical_reports/4987958562.jpg
# 334    M      medical_reports/740477.jpg
# 335    F      medical_reports/747015.jpg
# 336    M  medical_reports/4445753947.jpg
# 337    M      medical_reports/745095.jpg
# 338    M      medical_reports/744243.jpg
# 339    M      medical_reports/746770.jpg
# 340    F      medical_reports/696401.pdf
# 341    M      medical_reports/736363.jpg
# 342    M      medical_reports/H28616.jpg
#
# [343 rows x 7 columns]

# %%
no_definite_diagnosis=records.loc[records["Diagnosis"].isna()]

# %%
no_definite_diagnosis["Patient"].values.tolist()
# Out:
# ['746516',
#  '752665',
#  '380577',
#  '570034',
#  '559279',
#  '751516',
#  '742763',
#  '748127',
#  '6129041934',
#  '751024',
#  '740069',
#  '749805',
#  '752662',
#  '746526',
#  '665253',
#  'H14404',
#  '698711',
#  'M89313',
#  '4567206215',
#  '733266',
#  '4688493924',
#  '739357',
#  '749498',
#  '630043',
#  '747132',
#  '749835',
#  '753040',
#  '747860',
#  '752446',
#  '728569',
#  '749815',
#  '744378',
#  '740093',
#  '662198',
#  '751165']

# %%
print (len(no_definite_diagnosis["Patient"].values.tolist()))
# Out:
# 35

# %%
import pandas as pd
biomarkers=load_config_file("immuno.json")
biomarker_pd=pd.DataFrame(biomarkers)
biomarkers=[el.lower() for el in list(flatten(biomarker_pd.values.tolist())) if isinstance(el, str)]

# %%
biomarker_pd["Muscle cells"]["immuno markers"]
# Out:
# ['Actin', 'Caldesmon', 'Desmin', 'Myoglobin', 'Myogenin', 'myod1', '\\bSMA\\b']

# %%
fusion_proteins=pd.read_csv("fusion_genes.txt", sep='\t')
biomarkers=biomarkers+fusion_proteins["IHC MARKER"].values.tolist()
biomarkers=[el.lower() for el in biomarkers]

# %%
biomarkers= ('|'.join(biomarkers))

# %%
biomarkers_regex = "({})".format(biomarkers)

# %%
biomarkers_regex
# Out:
# '(alpha fetoprotein|oct3/4|sall4|cd30|placental alkaline phosphatase (plap)|cytokeratin|ema|actin|caldesmon|desmin|myoglobin|myogenin|myod1|\\bsma\\b|cd10|cd45|cd79a|cd15|cd1a|cd68|myeloperoxidate|tdt|cd21|cd23|cd35|cd117|cd138|von willebrand factor|cd31|cd34|cdk4|ck5/6|erg|neuron-specific enolase|cd56|cd57|pgp5.5|synaptophysin|chromogranin|neuron|neurofilaments|s100|hmb45|mitf|melana|dog1|kit|pax8|beta-catenin|mdm2|smarcb1|sdh|brachyury|p63|gfap|hmga2|h3g34w|h3k36m|pax3|tle1|f13a|pgr| er|stat6|bgr1|ini1|p16|calretinin|cam5.2|sox10|state|k7|k8|k18|k19|k13|k14|k17|k20|ae1/ae3|fli1|erg|ap1β|tle1|alk|alk|ros1|nr4a3|bcl-2|wt1|myc|nut|bcl6|tfe3|zap70|muc4|ccnb3|muc4)'

# %%
#weak_positivity= "There is (.*(scanty|weak)).*?(expression|positivity)|weak staining for [a-zA-Z0-9&._$-]+"
negative=["\s*negative for\s*([^.]*)",
            "(.*?)are negative",
            "(.*?)interpreted as negative"]

# %%
positive=["(?:[A-Za-z]+){1,7}positive for\s*(.*?(while|with|negative)|([^.|;]*))",
           "(?:t|T)here is.*?(expression|positivity)(\s*of)*(.*?(while|with|negative)|([^.|;]*))",
           "(.*?)\s(?:shows|show)\s.*?expression(\s*of)*(.*?(while|with|negative)|([^.|;]*))",
           "(?:[A-Za-z]+ ){1,4}\s(?:is|appears)\s(.*?)positive",
           "(?:[A-Za-z]+ ){1,4}\s(?:stain(s)*\s[^.|;]*)",
            "(.*?)\s(?:show(s)*(.*?)staining)",
            "with(.*?)(expression|positivity)(\sof)*[^.|;]*",
            "(?:[A-Za-z]+ ){1,4}(?:appear(s)*)(.*?)retained in nuclei"]

significance_levels=["moderate(ly)*","weak(ly)*","weak(ly)* to moderate(ly)*",
                     "moderate(ly)* to strong(ly)*","scanty", "strong(ly)*",
                     "of uncertain significance","some","focal(ly)*","granular",
                     "nuclear","multifocal","cytoplasmic",
                     "diffuse(ly)*","scattered","peripheral"]

# %%
biomarkers_regex
# Out:
# '(alpha fetoprotein|oct3/4|sall4|cd30|placental alkaline phosphatase (plap)|cytokeratin|ema|actin|caldesmon|desmin|myoglobin|myogenin|myod1|\\bsma\\b|cd10|cd45|cd79a|cd15|cd1a|cd68|myeloperoxidate|tdt|cd21|cd23|cd35|cd117|cd138|von willebrand factor|cd31|cd34|cdk4|ck5/6|erg|neuron-specific enolase|cd56|cd57|pgp5.5|synaptophysin|chromogranin|neuron|neurofilaments|s100|hmb45|mitf|melana|dog1|kit|pax8|beta-catenin|mdm2|smarcb1|sdh|brachyury|p63|gfap|hmga2|h3g34w|h3k36m|pax3|tle1|f13a|pgr| er|stat6|bgr1|ini1|p16|calretinin|cam5.2|sox10|state|k7|k8|k18|k19|k13|k14|k17|k20|ae1/ae3|fli1|erg|ap1β|tle1|alk|alk|ros1|nr4a3|bcl-2|wt1|myc|nut|bcl6|tfe3|zap70|muc4|ccnb3|muc4)'

# %%
import os
from pdf2image import convert_from_path
import pytesseract
import nltk
import re
import collections
import cv2

pdf_dir="medical_reports"
positive_biomarkers=collections.defaultdict(list)
negative_biomarkers=collections.defaultdict(list)
pdf_files=os.listdir(pdf_dir)

for pdf_file in pdf_files:
   
    text=''
    if pdf_file.endswith(".pdf"):
            try:
                    images=convert_from_path(os.path.join(pdf_dir,pdf_file))
                    for image in images:
                        text += str(pytesseract.image_to_string(image))
                        text=text.replace("\n"," ")
            except exceptions.PDFPageCountError:
                    raise ValueError('Exception: PDFPageCountError for %s' % path)
    
    elif pdf_file.endswith(".jpg"):
            
            img = cv2.imread(os.path.join(pdf_dir,pdf_file))
            rotated=deskew(img)
            text += str(pytesseract.image_to_string(rotated))
            text=text.replace("\n"," ")
    text=text.replace("h- caldesmon","caldesmon")
    text=text.replace("$100","S100")
    text=text.replace("$OX10","SOX10")
    sentences = nltk.tokenize.sent_tokenize(text)
    patient_name=os.path.splitext(pdf_file)[0]
    
    for sentence in sentences:
        sentence=sentence.replace("(","")
        sentence=sentence.replace(")","")
        for positive_regex in positive:
            try:
                match=re.search(positive_regex, sentence, re.MULTILINE | re.DOTALL).group(0)
                 
                if match:                     
                    positive_biomarker=(list("".join(x) for x in re.findall(biomarkers_regex,match.lower())))
              
                    positive_biomarkers[patient_name].append(positive_biomarker)
#                     for marker in positive_biomarker:
#                         antigen_regex= r'(?:[A-Za-z]+ ){1,4}\b%s\b' % (marker.lower())
                        
#                         for significance in significance_levels:
                            
#                             previous_words= (re.findall(antigen_regex,match.lower()))
                            
                        
            except AttributeError:
                pass
        for negative_regex in negative:
            try:
                match=re.search(negative_regex, sentence, re.MULTILINE | re.DOTALL).group(0)
                if match:
                    negative_biomarker=(list("".join(x) for x in re.findall(biomarkers_regex,match.lower())))
                    negative_biomarkers[patient_name].append(negative_biomarker)
            except AttributeError:
                pass

# %%
with open('positive.json', 'w') as fp:
    json.dump(positive_biomarkers, fp)

# %%
with open('negative.json', 'w') as fp:
    json.dump(negative_biomarkers, fp)
